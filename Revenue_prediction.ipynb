# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('final_shop.csv')
df
# Out:
#                                             Ad Group     Month  Impressions  \
# 0             Shop - 1:1 - Desk - [shop coupon code]      July        16038
# 1                  Shop - 1:1 - Desk - [shop coupon]      July        36462
# 2           Shop - 1:1 - Desk - [shop discount code]      July         3635
# 3              Shop - 1:1 - Desk - [shop promo code]      July        26185
# 4                   Shop - 1:1 - Desk - [shop promo]      July          808
# ..                                               ...       ...          ...
# 185  Shop - Exact - Desk - Black Friday/Cyber Monday  November          257
# 186         Shop - 1:1 - Desk - [shop discount code]  November         7254
# 187                Shop - Exact - Desk - Coupon Code  November        18526
# 188   Shop - Exact - Mob - Black Friday/Cyber Monday  November         3662
# 189                 Shop - Exact - Desk - Promo Code  November        25592
#
#      Clicks   CTR  Conversions  Conv Rate   Cost   CPC  Sale Amount      P&L  \
# 0      6504  0.41         1166       0.10   6669  1.03    136770.05 -267.086
# 1     14367  0.39         2188       0.09  13746  0.96    283215.21 -483.951
# 2      1458  0.40          248       0.09   1606  1.10     39165.46  117.136
# 3     10418  0.40         2294       0.12  13278  1.27    284823.48 -235.921
# 4       282  0.35           61       0.15    391  1.39      7717.77  -53.604
# ..      ...   ...          ...        ...    ...   ...          ...      ...
# 185      24  0.09            7       0.28      3  0.14       898.80   41.946
# 186    2725  0.38          512       0.11   3182  1.17     66672.29   45.468
# 187    5553  0.30          919       0.10   5982  1.08    129556.90   64.552
# 188     266  0.07           24       0.09     44  0.17      3268.63  115.963
# 189    7726  0.30         1731       0.14  10914  1.41    236665.59  308.975
#
#      Revenue
# 0       6402
# 1      13262
# 2       1723
# 3      13042
# 4        337
# ..       ...
# 185       45
# 186     3227
# 187     6047
# 188      160
# 189    11223
#
# [190 rows x 12 columns]

# %%
df.head()
# Out:
#                                    Ad Group Month  Impressions  Clicks   CTR  \
# 0    Shop - 1:1 - Desk - [shop coupon code]  July        16038    6504  0.41
# 1         Shop - 1:1 - Desk - [shop coupon]  July        36462   14367  0.39
# 2  Shop - 1:1 - Desk - [shop discount code]  July         3635    1458  0.40
# 3     Shop - 1:1 - Desk - [shop promo code]  July        26185   10418  0.40
# 4          Shop - 1:1 - Desk - [shop promo]  July          808     282  0.35
#
#    Conversions  Conv Rate   Cost   CPC  Sale Amount      P&L  Revenue
# 0         1166       0.10   6669  1.03    136770.05 -267.086     6402
# 1         2188       0.09  13746  0.96    283215.21 -483.951    13262
# 2          248       0.09   1606  1.10     39165.46  117.136     1723
# 3         2294       0.12  13278  1.27    284823.48 -235.921    13042
# 4           61       0.15    391  1.39      7717.77  -53.604      337

# %%
df.describe()
# Out:
#          Impressions        Clicks         CTR  Conversions   Conv Rate  \
# count     190.000000    190.000000  190.000000   190.000000  190.000000
# mean    14077.363158   4865.805263    0.272105   505.242105    0.079737
# std     29771.686227  11348.529219    0.107894  1052.202922    0.052859
# min        35.000000      2.000000    0.050000     0.000000    0.000000
# 25%      1065.000000    264.500000    0.192500    24.000000    0.050000
# 50%      4969.000000    930.000000    0.285000    70.500000    0.070000
# 75%     13380.000000   4190.500000    0.360000   428.250000    0.100000
# max    276568.000000  99526.000000    0.470000  7563.000000    0.500000
#
#                Cost         CPC    Sale Amount          P&L       Revenue
# count    190.000000  190.000000     190.000000   190.000000    190.000000
# mean    3344.063158    0.791263   63416.180579  -386.361916   2957.684211
# std     6524.606753    0.403312  125414.656922   903.073776   5962.413097
# min        1.000000    0.140000       0.000000 -5672.271000      0.000000
# 25%      188.500000    0.480000    2985.135000  -294.977500    144.500000
# 50%      563.500000    0.635000   10274.105000   -75.978000    459.500000
# 75%     2967.000000    1.107500   59345.195000    -6.027500   2672.250000
# max    43542.000000    2.020000  886095.310000  1507.685000  42440.000000

# %%
print('no of rows:',df.shape[0])
print('no of columns:',df.shape[1])
# Out:
# no of rows: 190
# no of columns: 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ad Group     190 non-null    object
#  1   Month        190 non-null    object
#  2   Impressions  190 non-null    int64
#  3   Clicks       190 non-null    int64
#  4   CTR          190 non-null    float64
#  5   Conversions  190 non-null    int64
#  6   Conv Rate    190 non-null    float64
#  7   Cost         190 non-null    int64
#  8   CPC          190 non-null    float64
#  9   Sale Amount  190 non-null    float64
#  10  P&L          190 non-null    float64
#  11  Revenue      190 non-null    int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 17.9+ KB

# %%
df.isnull().sum()
# Out:
# Ad Group       0
# Month          0
# Impressions    0
# Clicks         0
# CTR            0
# Conversions    0
# Conv Rate      0
# Cost           0
# CPC            0
# Sale Amount    0
# P&L            0
# Revenue        0
# dtype: int64

# %%
x=df.iloc[:,2:11].values
x=df.iloc[:,9:10].values
y=df.iloc[:,11:].values

# %%
fig=plt.figure()
axs=fig.add_axes([0,0,1,1])
axs.scatter(x,y,color='red')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=regression.predict(x_test)

# %%
y_predict[1]
# Out:
# array([-66.14943274])

# %%
y_test[1]
# Out:
# array([8], dtype=int64)

# %%
df=pd.DataFrame({'Actual':y_test.flatten(),'predicated':y_predict.flatten()})
df
# Out:
#      Actual   predicated
# 0       268   240.433870
# 1         8   -66.149433
# 2      1591  1617.258561
# 3      3973  4098.690105
# 4       208   136.076225
# ..      ...          ...
# 147      41   -35.082703
# 148    1836  1886.608534
# 149     481   466.248997
# 150     573   559.636354
# 151    6766  6988.916329
#
# [152 rows x 2 columns]

# %%
sns.pairplot(df)
